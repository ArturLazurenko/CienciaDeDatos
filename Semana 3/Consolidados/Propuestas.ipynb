# %% [markdown]
# # Ejercicio 3.1

# %%
import pandas as pd

# Listas

numeros = [10, 20, 30, 40, 50]

# Diccionario
personas = [
    {"nombre": "Juan", "edad": 25, "salario": 30000},
    {"nombre": "Maria", "edad": 30, "salario": 50000},
    {"nombre": "Carlos", "edad": 22, "salario": 20000}
]

# DataFrame
df = pd.DataFrame(personas)

print(df)

# 2. LAMBDA

duplicar = lambda x: x * 2

print("Duplicar 5:", duplicar(5))


# 3. LIST COMPREHENSIONS

pares = [x for x in numeros if x % 20 == 0]

print("Números divisibles entre 20:", pares)


# 4. MANEJO DE ERRORES

try:
    numero = int(input("Ingresa un número: "))
    resultado = 10 / numero
    print("Resultado:", resultado)
except ZeroDivisionError:
    print("Error: No se puede dividir entre cero.")
except ValueError:
    print("Error: Debes ingresar un número válido.")
finally:
    print("Fin del bloque try-except.")

# 5. EJERCICIOS 

# Ejercicio 1: Suma de una lista
def suma_lista(lista):
    return sum(lista)

print("\nEjercicio 1:", suma_lista(numeros))


# Ejercicio 2: Número mayor
def numero_mayor(lista):
    return max(lista)

print("Ejercicio 2:", numero_mayor(numeros))


# Ejercicio 3: Contar elementos mayores a 25
def mayores_25(lista):
    return len([x for x in lista if x > 25])

print("Ejercicio 3:", mayores_25(numeros))


# Ejercicio 4: Convertir nombres a mayúsculas
def nombres_mayusculas(lista_personas):
    return [p["nombre"].upper() for p in lista_personas]

print("Ejercicio 4:", nombres_mayusculas(personas))


# Ejercicio 5: Promedio de salarios
def promedio_salarios(lista_personas):
    salarios = [p["salario"] for p in lista_personas]
    return sum(salarios) / len(salarios)

print("Ejercicio 5:", promedio_salarios(personas))
# Out:
#    nombre  edad  salario
# 0    Juan    25    30000
# 1   Maria    30    50000
# 2  Carlos    22    20000
# Duplicar 5: 10
# Números divisibles entre 20: [20, 40]
# Error: Debes ingresar un número válido.
# Fin del bloque try-except.
#
# Ejercicio 1: 150
# Ejercicio 2: 50
# Ejercicio 3: 3
# Ejercicio 4: ['JUAN', 'MARIA', 'CARLOS']
# Ejercicio 5: 33333.333333333336

# %% [markdown]
# # Ejercicio 3.2

# %%
import pandas as pd

# Cargar el dataset
ruta = "../DataSets/Titanic-Dataset.csv"
df = pd.read_csv(ruta)


# 1. Mostrar 10 filas
print("Primeras 10 filas:")
display(df.head(10))


# 2. Info del dataset
print("Información del dataset:")
df.info()

# 3. Estadisticas descriptivas
print("Estadísticas básicas:")
display(df.describe())

# 4. Tipos de datos
print("Tipos de datos:")
print(df.dtypes)

# 5. Valores nulos
print("Valores nulos por columna:")
print(df.isnull().sum())

# 6. Resumen general (extra útil)
print("Resumen general:")
display(df.describe(include='all'))
# Out:
# Primeras 10 filas:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Actividad 3.3

# %%
import pandas as pd

# Cargar dataset 
ruta = "../DataSets/Titanic-Dataset.csv"
df = pd.read_csv(ruta)


# ESTADO INICIAL
print("=== ESTADO INICIAL ===")
print("Dimensiones:", df.shape)
print("\nValores nulos:")
print(df.isnull().sum())
print("\nDuplicados:", df.duplicated().sum())
display(df.head())

# Rellenar valores nulos

# Edad = promedio
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Embarque = moda
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Cabin = eliminar columna
if 'Cabin' in df.columns:
    df.drop(columns=['Cabin'], inplace=True)

# Eliminar duplicados
df = df.drop_duplicates()

# convertir a categoría
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')

# Estandarizar nombres de columnas
df.columns = df.columns.str.lower().str.strip().str.replace(" ", "_")

# tamaño de familia
df['family_size'] = df['sibsp'] + df['parch'] + 1

# pasajero solo
df['is_alone'] = df['family_size'].apply(lambda x: 1 if x == 1 else 0)


# ESTADO FINAL
print("=== ESTADO FINAL ===")
print("Dimensiones:", df.shape)
print("\nValores nulos:")
print(df.isnull().sum())
print("\nDuplicados:", df.duplicated().sum())
display(df.head())
# Out:
# === ESTADO INICIAL ===
# Dimensiones: (891, 12)
#
# Valores nulos:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Duplicados: 0
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Actividad 3.4

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Histograma
plt.figure()
plt.hist(df['age'])
plt.title("Distribución de edades")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# Gráfico de barras
plt.figure()
df['survived'].value_counts().plot(kind='bar')
plt.title("Supervivencia de pasajeros")
plt.xlabel("Sobrevivió (0 = No, 1 = Sí)")
plt.ylabel("Cantidad")
plt.show()

# Gráfico de dispersión
plt.figure()
plt.scatter(df['age'], df['fare'])
plt.title("Edad vs Tarifa")
plt.xlabel("Edad")
plt.ylabel("Tarifa")
plt.show()

# Mapa de calor de correlaciones
plt.figure()
corr = df.corr(numeric_only=True)

plt.imshow(corr)
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Mapa de calor de correlaciones")
plt.show()

# %% [markdown]
# ## Interpretaciones
#
# ### Histograma
#
# - La mayoria de pasajeros tenian edades de entre 20 a 40 años, la mayoria teniendo 30
# - Eran muy pocas personas mayores
#
# ### Grafico de barras
#
# - Mas de la mitad de los pasajeros no sobrevivio
#
# ### Gráfico de dispersión
#
# - No hay una relación fuerte entre edad y tarifa
# - Hay Bastantes tarifas bajas
#
# ### Mapa de calor de correlaciones
#
# - La edad, tarifa y el ID tiene una correlacion debil o nula con las otras
# - Family size es la que mejor correlacion con otras tiene, por ejemplo is_alone
